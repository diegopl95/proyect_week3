# %%
# UFC PREDICTION MODEL

# %%
from bs4 import BeautifulSoup as bs 
import requests as req

# %%
# UFC URL

url = 'http://www.ufcstats.com/statistics/fighters'
req.get(url)
# Out:
# <Response [200]>

# %%
html = req.get(url).text
sopa = bs(html, 'html.parser')

# %%
cabeceras = sopa.find('table').find('tr')  
filas = sopa.find('table').find_all('tr')[2:]

# %%
cabeceras = [e.text.strip() for e in cabeceras.find_all('th')]

# %%
[e.text.strip() for e in filas[1].find_all('td')]
# Out:
# ['Danny',
#  'Abbadi',
#  'The Assassin',
#  '5\' 11"',
#  '155 lbs.',
#  '--',
#  'Orthodox',
#  '4',
#  '6',
#  '0',
#  '']

# %%
tabla = [[e.text.strip() for e in f.find_all('td')] for f in filas]

# %%
import pandas as pd

# %%
mcgregor = pd.DataFrame(tabla, columns=cabeceras)
mcgregor
# Out:
#        First          Last              Nickname     Ht.       Wt.  Reach  \
# 0        Tom         Aaron                            --  155 lbs.     --
# 1      Danny        Abbadi          The Assassin  5' 11"  155 lbs.     --
# 2    Nariman       Abbasov             Bayraktar   5' 8"  155 lbs.  66.0"
# 3      David        Abbott                  Tank   6' 0"  265 lbs.     --
# 4      Hamdy    Abdelwahab            The Hammer   6' 2"  264 lbs.  72.0"
# 5     Shamil  Abdurakhimov                 Abrek   6' 3"  235 lbs.  76.0"
# 6   Hiroyuki           Abe               Abe Ani   5' 6"  145 lbs.     --
# 7     Daichi           Abe                        5' 11"  170 lbs.  71.0"
# 8       Papy         Abedi               Makambo  5' 11"  185 lbs.     --
# 9    Ricardo         Abreu               Demente  5' 11"  185 lbs.     --
# 10   Klidson         Abreu            White Bear   6' 0"  205 lbs.  74.0"
# 11    Cyborg         Abreu                            --        --     --
# ...

# %%
pd.read_html('http://www.ufcstats.com/statistics/fighters?char=a&page=1')[0]
# Out:
#        First          Last              Nickname     Ht.       Wt.  Reach  \
# 0        NaN           NaN                   NaN     NaN       NaN    NaN
# 1        Tom         Aaron                   NaN      --  155 lbs.     --
# 2      Danny        Abbadi          The Assassin  5' 11"  155 lbs.     --
# 3    Nariman       Abbasov             Bayraktar   5' 8"  155 lbs.  66.0"
# 4      David        Abbott                  Tank   6' 0"  265 lbs.     --
# 5      Hamdy    Abdelwahab            The Hammer   6' 2"  264 lbs.  72.0"
# 6     Shamil  Abdurakhimov                 Abrek   6' 3"  235 lbs.  76.0"
# 7   Hiroyuki           Abe               Abe Ani   5' 6"  145 lbs.     --
# 8     Daichi           Abe                   NaN  5' 11"  170 lbs.  71.0"
# 9       Papy         Abedi               Makambo  5' 11"  185 lbs.     --
# 10   Ricardo         Abreu               Demente  5' 11"  185 lbs.     --
# 11   Klidson         Abreu            White Bear   6' 0"  205 lbs.  74.0"
# ...

# %%
url = 'http://www.ufcstats.com/statistics/fighters?char=a&page=2'

# %%
lst_df = []

for i in range(1, 9):
    print(i)
    url = f'http://www.ufcstats.com/statistics/fighters?char=a&page={i}'
    mcgregor = pd.read_html(url)[0]
    lst_df.append(df)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
# 7
# 8

# %%
mcgregor = pd.concat(lst_df)
mcgregor.reset_index(drop = True, inplace = True)
mcgregor
# Out:
#        First           Last               Nickname     Ht.       Wt.  Reach  \
# 0        NaN            NaN                    NaN     NaN       NaN    NaN
# 1    Antonio         Arroyo                    NaN   6' 3"  185 lbs.  73.0"
# 2     Gilles         Arsene                    NaN   5' 9"  190 lbs.     --
# 3       Veta        Arteaga                    NaN   5' 7"  125 lbs.     --
# 4      Cesar     Arzamendia                   Goku  5' 11"  155 lbs.     --
# ..       ...            ...                    ...     ...       ...    ...
# 195  Bazigit         Atajev                   Volk   6' 1"  230 lbs.     --
# 196     Rich       Attonito        The Raging Bull  5' 10"  170 lbs.  72.0"
# 197  Olivier  Aubin-Mercier  The Canadian Gangster   5' 9"  155 lbs.  70.0"
# 198      Pat      Audinwood      Awesomely Awesome   6' 0"  155 lbs.     --
# 199     Jose        Augusto                   Gugu   6' 3"  251 lbs.     --
#
#        Stance     W    L    D  Belt
# ...

# %%
mcgregor.dropna(how='all', inplace= True)
mcgregor.reset_index(drop = True, inplace = True)
mcgregor
# Out:
#        First           Last               Nickname     Ht.       Wt.  Reach  \
# 0    Antonio         Arroyo                    NaN   6' 3"  185 lbs.  73.0"
# 1     Gilles         Arsene                    NaN   5' 9"  190 lbs.     --
# 2       Veta        Arteaga                    NaN   5' 7"  125 lbs.     --
# 3      Cesar     Arzamendia                   Goku  5' 11"  155 lbs.     --
# 4      Teddy            Ash                   Bear   6' 1"  185 lbs.  73.0"
# ..       ...            ...                    ...     ...       ...    ...
# 187  Bazigit         Atajev                   Volk   6' 1"  230 lbs.     --
# 188     Rich       Attonito        The Raging Bull  5' 10"  170 lbs.  72.0"
# 189  Olivier  Aubin-Mercier  The Canadian Gangster   5' 9"  155 lbs.  70.0"
# 190      Pat      Audinwood      Awesomely Awesome   6' 0"  155 lbs.     --
# 191     Jose        Augusto                   Gugu   6' 3"  251 lbs.     --
#
#        Stance     W    L    D  Belt
# ...

# %%
pd.read_html('http://www.ufcstats.com/statistics/fighters?char=a&page=all')[0].dropna(how='all')
# Out:
#        First        Last         Nickname     Ht.       Wt.  Reach    Stance  \
# 1        Tom       Aaron              NaN      --  155 lbs.     --       NaN
# 2      Danny      Abbadi     The Assassin  5' 11"  155 lbs.     --  Orthodox
# 3    Nariman     Abbasov        Bayraktar   5' 8"  155 lbs.  66.0"  Orthodox
# 4      David      Abbott             Tank   6' 0"  265 lbs.     --    Switch
# 5      Hamdy  Abdelwahab       The Hammer   6' 2"  264 lbs.  72.0"  Southpaw
# ..       ...         ...              ...     ...       ...    ...       ...
# 210      Abu     Azaitar  Captain Morocco   5' 9"  185 lbs.  76.0"  Orthodox
# 211   Ottman     Azaitar        Bulldozer   5' 8"  155 lbs.  71.0"    Switch
# 212     Luiz     Azeredo              NaN   5' 9"  154 lbs.     --  Orthodox
# 213  Luciano     Azevedo              NaN   6' 3"  161 lbs.     --  Orthodox
# 214   Hunter       Azure              NaN   5' 8"  145 lbs.  69.0"  Orthodox
#
#         W     L    D  Belt
# ...

# %%
# proyecto estructura

# 1. data extraction (scrapping, apis, o database)
# 2. data cleaning, data performing, maquillaje con el objetivo de operar con los datos y encaminarte hacia las conclusiones
# 3. hallazgos y presentación
# 4. Proximos pasos, hacia donde va el proyecto

# %%
mcgregor.head()
# Out:
#      First        Last Nickname     Ht.       Wt.  Reach    Stance     W    L  \
# 0  Antonio      Arroyo      NaN   6' 3"  185 lbs.  73.0"  Orthodox   9.0  5.0
# 1   Gilles      Arsene      NaN   5' 9"  190 lbs.     --  Southpaw   1.0  1.0
# 2     Veta     Arteaga      NaN   5' 7"  125 lbs.     --       NaN   3.0  1.0
# 3    Cesar  Arzamendia     Goku  5' 11"  155 lbs.     --  Orthodox   8.0  3.0
# 4    Teddy         Ash     Bear   6' 1"  185 lbs.  73.0"    Switch  14.0  5.0
#
#      D  Belt
# 0  0.0   NaN
# 1  0.0   NaN
# 2  0.0   NaN
# 3  0.0   NaN
# 4  0.0   NaN

# %%
mcgregor['win_ratio'] = mcgregor.W / (mcgregor.W + mcgregor.L + mcgregor.D)

# %%
mcgregor.head()
# Out:
#      First        Last Nickname     Ht.       Wt.  Reach    Stance     W    L  \
# 0  Antonio      Arroyo      NaN   6' 3"  185 lbs.  73.0"  Orthodox   9.0  5.0
# 1   Gilles      Arsene      NaN   5' 9"  190 lbs.     --  Southpaw   1.0  1.0
# 2     Veta     Arteaga      NaN   5' 7"  125 lbs.     --       NaN   3.0  1.0
# 3    Cesar  Arzamendia     Goku  5' 11"  155 lbs.     --  Orthodox   8.0  3.0
# 4    Teddy         Ash     Bear   6' 1"  185 lbs.  73.0"    Switch  14.0  5.0
#
#      D  Belt  win_ratio
# 0  0.0   NaN   0.642857
# 1  0.0   NaN   0.500000
# 2  0.0   NaN   0.750000
# 3  0.0   NaN   0.727273
# 4  0.0   NaN   0.736842

# %%
mcgregor.shape
# Out:
# (192, 12)

# %%
mcgregor['loss_ratio'] = mcgregor.L / (mcgregor.W + mcgregor.L + mcgregor.D)

# %%
mcgregor.head()
# Out:
#      First        Last Nickname     Ht.       Wt.  Reach    Stance     W    L  \
# 0  Antonio      Arroyo      NaN   6' 3"  185 lbs.  73.0"  Orthodox   9.0  5.0
# 1   Gilles      Arsene      NaN   5' 9"  190 lbs.     --  Southpaw   1.0  1.0
# 2     Veta     Arteaga      NaN   5' 7"  125 lbs.     --       NaN   3.0  1.0
# 3    Cesar  Arzamendia     Goku  5' 11"  155 lbs.     --  Orthodox   8.0  3.0
# 4    Teddy         Ash     Bear   6' 1"  185 lbs.  73.0"    Switch  14.0  5.0
#
#      D  Belt  win_ratio  loss_ratio
# 0  0.0   NaN   0.642857    0.357143
# 1  0.0   NaN   0.500000    0.500000
# 2  0.0   NaN   0.750000    0.250000
# 3  0.0   NaN   0.727273    0.272727
# 4  0.0   NaN   0.736842    0.263158

# %%
mcgregor['decision_ratio'] = mcgregor.D / (mcgregor.W + mcgregor.L + mcgregor.D)

# %%
mcgregor.head()
# Out:
#      First        Last Nickname     Ht.       Wt.  Reach    Stance     W    L  \
# 0  Antonio      Arroyo      NaN   6' 3"  185 lbs.  73.0"  Orthodox   9.0  5.0
# 1   Gilles      Arsene      NaN   5' 9"  190 lbs.     --  Southpaw   1.0  1.0
# 2     Veta     Arteaga      NaN   5' 7"  125 lbs.     --       NaN   3.0  1.0
# 3    Cesar  Arzamendia     Goku  5' 11"  155 lbs.     --  Orthodox   8.0  3.0
# 4    Teddy         Ash     Bear   6' 1"  185 lbs.  73.0"    Switch  14.0  5.0
#
#      D  Belt  win_ratio  loss_ratio  decision_ratio
# 0  0.0   NaN   0.642857    0.357143             0.0
# 1  0.0   NaN   0.500000    0.500000             0.0
# 2  0.0   NaN   0.750000    0.250000             0.0
# 3  0.0   NaN   0.727273    0.272727             0.0
# 4  0.0   NaN   0.736842    0.263158             0.0

# %%
mcgregor['Win-Loss Difference'] = df['W'] - df['L']

# %%
mcgregor.head()
# Out:
#      First        Last Nickname     Ht.       Wt.  Reach    Stance     W    L  \
# 0  Antonio      Arroyo      NaN   6' 3"  185 lbs.  73.0"  Orthodox   9.0  5.0
# 1   Gilles      Arsene      NaN   5' 9"  190 lbs.     --  Southpaw   1.0  1.0
# 2     Veta     Arteaga      NaN   5' 7"  125 lbs.     --       NaN   3.0  1.0
# 3    Cesar  Arzamendia     Goku  5' 11"  155 lbs.     --  Orthodox   8.0  3.0
# 4    Teddy         Ash     Bear   6' 1"  185 lbs.  73.0"    Switch  14.0  5.0
#
#      D  Belt  win_ratio  loss_ratio  decision_ratio  Win-Loss Difference
# 0  0.0   NaN   0.642857    0.357143             0.0                  NaN
# 1  0.0   NaN   0.500000    0.500000             0.0                  4.0
# 2  0.0   NaN   0.750000    0.250000             0.0                  0.0
# 3  0.0   NaN   0.727273    0.272727             0.0                  2.0
# 4  0.0   NaN   0.736842    0.263158             0.0                  5.0

# %%
import pandas as pd
mcgregor = mcgregor.drop('decision_ratio', axis=1)

# %%
mcgregor.head()
# Out:
#      First        Last Nickname     Ht.       Wt.  Reach    Stance     W    L  \
# 0  Antonio      Arroyo      NaN   6' 3"  185 lbs.  73.0"  Orthodox   9.0  5.0
# 1   Gilles      Arsene      NaN   5' 9"  190 lbs.     --  Southpaw   1.0  1.0
# 2     Veta     Arteaga      NaN   5' 7"  125 lbs.     --       NaN   3.0  1.0
# 3    Cesar  Arzamendia     Goku  5' 11"  155 lbs.     --  Orthodox   8.0  3.0
# 4    Teddy         Ash     Bear   6' 1"  185 lbs.  73.0"    Switch  14.0  5.0
#
#      D  Belt  win_ratio  loss_ratio  Win-Loss Difference
# 0  0.0   NaN   0.642857    0.357143                  NaN
# 1  0.0   NaN   0.500000    0.500000                  4.0
# 2  0.0   NaN   0.750000    0.250000                  0.0
# 3  0.0   NaN   0.727273    0.272727                  2.0
# 4  0.0   NaN   0.736842    0.263158                  5.0

# %%
mcgregor = mcgregor.drop('D', axis=1)

# %%
mcgregor.head()
# Out:
#      First        Last Nickname     Ht.       Wt.  Reach    Stance     W    L  \
# 0  Antonio      Arroyo      NaN   6' 3"  185 lbs.  73.0"  Orthodox   9.0  5.0
# 1   Gilles      Arsene      NaN   5' 9"  190 lbs.     --  Southpaw   1.0  1.0
# 2     Veta     Arteaga      NaN   5' 7"  125 lbs.     --       NaN   3.0  1.0
# 3    Cesar  Arzamendia     Goku  5' 11"  155 lbs.     --  Orthodox   8.0  3.0
# 4    Teddy         Ash     Bear   6' 1"  185 lbs.  73.0"    Switch  14.0  5.0
#
#    Belt  win_ratio  loss_ratio  Win-Loss Difference
# 0   NaN   0.642857    0.357143                  NaN
# 1   NaN   0.500000    0.500000                  4.0
# 2   NaN   0.750000    0.250000                  0.0
# 3   NaN   0.727273    0.272727                  2.0
# 4   NaN   0.736842    0.263158                  5.0

# %%
mcgregor = mcgregor.drop('Belt', axis=1)

# %%
mcgregor.head()
# Out:
#      First        Last Nickname     Ht.       Wt.  Reach    Stance     W    L  \
# 0  Antonio      Arroyo      NaN   6' 3"  185 lbs.  73.0"  Orthodox   9.0  5.0
# 1   Gilles      Arsene      NaN   5' 9"  190 lbs.     --  Southpaw   1.0  1.0
# 2     Veta     Arteaga      NaN   5' 7"  125 lbs.     --       NaN   3.0  1.0
# 3    Cesar  Arzamendia     Goku  5' 11"  155 lbs.     --  Orthodox   8.0  3.0
# 4    Teddy         Ash     Bear   6' 1"  185 lbs.  73.0"    Switch  14.0  5.0
#
#    win_ratio  loss_ratio  Win-Loss Difference
# 0   0.642857    0.357143                  NaN
# 1   0.500000    0.500000                  4.0
# 2   0.750000    0.250000                  0.0
# 3   0.727273    0.272727                  2.0
# 4   0.736842    0.263158                  5.0

# %%
mcgregor = mcgregor.drop('Nickname', axis=1)

# %%
mcgregor
# Out:
#        First           Last     Ht.       Wt.  Reach    Stance     W    L  \
# 0    Antonio         Arroyo   6' 3"  185 lbs.  73.0"  Orthodox   9.0  5.0
# 1     Gilles         Arsene   5' 9"  190 lbs.     --  Southpaw   1.0  1.0
# 2       Veta        Arteaga   5' 7"  125 lbs.     --       NaN   3.0  1.0
# 3      Cesar     Arzamendia  5' 11"  155 lbs.     --  Orthodox   8.0  3.0
# 4      Teddy            Ash   6' 1"  185 lbs.  73.0"    Switch  14.0  5.0
# ..       ...            ...     ...       ...    ...       ...   ...  ...
# 187  Bazigit         Atajev   6' 1"  230 lbs.     --  Orthodox  17.0  1.0
# 188     Rich       Attonito  5' 10"  170 lbs.  72.0"  Orthodox  10.0  5.0
# 189  Olivier  Aubin-Mercier   5' 9"  155 lbs.  70.0"  Southpaw  11.0  5.0
# 190      Pat      Audinwood   6' 0"  155 lbs.     --  Orthodox  11.0  2.0
# 191     Jose        Augusto   6' 3"  251 lbs.     --       NaN   6.0  2.0
#
#      win_ratio  loss_ratio  Win-Loss Difference
# ...

# %%
mcgregor.head()
# Out:
#      First        Last     Ht.       Wt.  Reach    Stance     W    L  \
# 0  Antonio      Arroyo   6' 3"  185 lbs.  73.0"  Orthodox   9.0  5.0
# 1   Gilles      Arsene   5' 9"  190 lbs.     --  Southpaw   1.0  1.0
# 2     Veta     Arteaga   5' 7"  125 lbs.     --       NaN   3.0  1.0
# 3    Cesar  Arzamendia  5' 11"  155 lbs.     --  Orthodox   8.0  3.0
# 4    Teddy         Ash   6' 1"  185 lbs.  73.0"    Switch  14.0  5.0
#
#    win_ratio  loss_ratio  Win-Loss Difference
# 0   0.642857    0.357143                  NaN
# 1   0.500000    0.500000                  4.0
# 2   0.750000    0.250000                  0.0
# 3   0.727273    0.272727                  2.0
# 4   0.736842    0.263158                  5.0
